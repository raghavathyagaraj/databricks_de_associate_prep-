# %% [markdown]
# ### Orders Data
# - There are certain data format issues in the orders file,the json is not in correct format
# - For this reason we are gonna select using the text
# - First we read using the json and see the error
# - Then we will read using the text format and fix the issue and then read again using the json from the cleaned data

# %% [markdown]
# #### 1.Query Orders File using JSON format

# %%
spark.read.json('/Volumes/gizmobox/landing/operational_data/orders').display()

# %%
df_orders =spark.read.text('/Volumes/gizmobox/landing/operational_data/orders')
display(df_orders)

# %%
df_orders.writeTo('gizmobox.bronze.py_orders').createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_orders;
