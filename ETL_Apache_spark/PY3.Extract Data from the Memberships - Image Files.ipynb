# %% [markdown]
# ### Extract Data from the Memberships - Image Files
# - 1.Query Memberships File Using binaryFile Format
# - 2.Create Memberships View in Bronze Schema

# %% [markdown]
# ###1.Query Memberships File Using binaryFile Format

# %%
df_membership = spark.read.format("binaryFile").load("/Volumes/gizmobox/landing/operational_data/memberships/*/*.png")
df_membership.display()

# %%
df_membership.writeTo("gizmobox.bronze.py_membership").createOrReplace()
